# %%
from lk_scraper import Scraper

# %%
scraper = Scraper()
# Out:
# Loading configuration file /Users/jqueguin/.lk_scraper/config.yml
# Loading rules file /Users/jqueguin/.lk_scraper/scraper_rules.json
# Loading configuration file /Users/jqueguin/.lk_scraper/config.yml
# Loading rules file /Users/jqueguin/.lk_scraper/scraper_rules.json
# Driver loaded
# Cookies loaded

# %%
apple = scraper.get_object(object_name='company', object_id='apple')
# Out:
# scraping : https://www.linkedin.com/company/apple/
# scraping : https://www.linkedin.com/search/results/people/?facetCurrentCompany=["162479"]&page=1
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=162479&start=1
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=162479&start=1&start=2
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=162479&start=1&start=2&start=3
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=162479&start=1&start=2&start=3&start=4
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=162479&start=1&start=2&start=3&start=4&start=5
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=162479&start=1&start=2&start=3&start=4&start=5&start=6
# ...

# %%
jlqueguiner = scraper.get_object(object_name='profil', object_id='jlqueguiner')
# Out:
# scraping : https://www.linkedin.com/in/jlqueguiner/

# %%
jlqueguiner
# Out:
# {'FullProfilePosition': [{'dateRange': {'start': {'month': 9,
#      'year': 2008,
#      '$type': 'com.linkedin.common.Date'},
#     'end': {'month': 12, 'year': 2011, '$type': 'com.linkedin.common.Date'},
#     '$type': 'com.linkedin.common.DateRange'},
#    'multiLocaleCompanyName': {'en_US': "Arts et Métiers ParisTech - École Nationale Supérieure d'Arts et Métiers"},
#    'companyName': "Arts et Métiers ParisTech - École Nationale Supérieure d'Arts et Métiers",
#    '*company': 'urn:li:fsd_company:1280025',
#    'title': 'MSc. Student in mecanical and industrial engineering',
#    'companyUrn': 'urn:li:fsd_company:1280025',
#    'entityUrn': 'urn:li:fsd_profilePosition:(ACoAAAZZM00BEZ1khtdIdKiAX_Wf0Id-G08JUBw,193664622)',
#    'multiLocaleTitle': {'en_US': 'MSc. Student in mecanical and industrial engineering'}},
#   {'dateRange': {'start': {'month': 2,
#      'year': 2013,
#      '$type': 'com.linkedin.common.Date'},
# ...

# %%
companies_infos = list()
companies = ['google', 'apple']

for company_name in companies:
    companies_infos[company_name] = scraper.get_object(object_name='company', object_id=company_name)
# Out:
# scraping : https://www.linkedin.com/company/google/
# Loading configuration file /Users/jqueguin/.lk_scraper/config.yml
# Loading rules file /Users/jqueguin/.lk_scraper/scraper_rules.json
# Driver loaded
# Cookies loaded
# scraping : https://www.linkedin.com/search/results/people/?facetCurrentCompany=["1441"]&page=1
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=1441&start=1
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=1441&start=1&start=2
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=1441&start=1&start=2&start=3
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=1441&start=1&start=2&start=3&start=4
# scraping : https://www.linkedin.com/jobs/search/?locationId=OTHERS.worldwide&f_C=1441&start=1&start=2&start=3&start=4&start=5
# ...

# %%
companies_infos
# Out:
# [{'FollowingInfo': {'followerCount': None},
#   'WebFullCompanyMain': {'staffCount': 192000,
#    'companyEmployeesSearchPageUrl': 'https://www.linkedin.com/vsearch/p?f_CC=1441',
#    'acquirerCompany': None,
#    'phone': None,
#    'entityUrn': 'urn:li:fs_normalized_company:1441',
#    'headquarter': {'country': 'US',
#     'geographicArea': 'CA',
#     'city': 'Mountain View',
#     'postalCode': '94043',
#     'line1': '1600 Amphitheatre Parkway',
#     '$type': 'com.linkedin.common.Address'},
#    'universalName': 'google',
#    'companyPageUrl': 'https://careers.google.com/?src=Online/LinkedIn/linkedin_profilepage&utm_source=linkedin&utm_medium=profilepage&utm_campaign=profilepage',
#    'url': 'https://www.linkedin.com/company/1441',
#    'jobSearchPageUrl': 'https://www.linkedin.com/jobs/search?locationId=OTHERS%2Eworldwide&f_C=1441%2C791962%2C2374003%2C18950635%2C16140%2C10440912',
#    'staffingCompany': False,
#    'staffCountRange': {'start': 10001,
# ...
